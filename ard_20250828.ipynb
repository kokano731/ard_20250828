# %% [markdown]
# # 環境
#
# WSL、Ubuntu、VScode、CUDA Toolkit、Jupyter Notebook
#
# 参考
# https://www.kkaneko.jp/tools/wsl/wsl_tensorflow2.html

# %%
import torch
from diffusers import DiffusionPipeline

torch.cuda.empty_cache()

model_id = 'stable-diffusion-v1-5/stable-diffusion-v1-5'

device = 'cuda'
pipe = DiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float16
).to(device)

prompt = 'a photograph of an astronaut riding a horse'
img = pipe(
    prompt,
    num_inference_steps=23,
    width=512,
    height=512,
    seed = 10
).images[0]
# img.save('test.jpg')
torch.cuda.empty_cache()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/23 [00:00<?, ?it/s]

# %% [markdown]
# Loading pipeline components...: 100%
#  7/7 [00:06<00:00,  1.16it/s]
#
# 100%
#  23/23 [00:03<00:00,  7.09it/s]

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
import torch
from diffusers import DiffusionPipeline

model_id = 'stable-diffusion-v1-5/stable-diffusion-v1-5'

device = 'cpu'
pipe = DiffusionPipeline.from_pretrained(
    model_id
).to(device)

prompt = 'a photograph of an astronaut riding a horse'
img = pipe(
    prompt,
    num_inference_steps=23,
    width=512,
    height=512,
    seed = 10
).images[0]
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/23 [00:00<?, ?it/s]

# %% [markdown]
# Loading pipeline components...: 100%
#  7/7 [00:00<00:00, 10.37it/s]
#
# 100%
#  23/23 [04:03<00:00,  9.97s/it]

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
